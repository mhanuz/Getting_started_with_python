# %%
import pandas as pd

# %%
import numpy as  np

# %%
people={
    'first':['corey','jan','jon','chris',None,np.nan,'ab','parnel'],
    'last':['schafer','deo','dan','henry',np.nan,np.nan,'cd','wine'],
    'email':['corey@gmail.com','jan@gmail.com',None,'henry@gmail.com','kopal@gmail.com','pura@gmail.com',None,'wine@gmail.com'],
    'age':[np.nan,35,43,23,np.nan,54,53,67]
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 2     jon      dan             None  43.0
# 3   chris    henry  henry@gmail.com  23.0
# 4    None      NaN  kopal@gmail.com   NaN
# 5     NaN      NaN   pura@gmail.com  54.0
# 6      ab       cd             None  53.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.dropna()
# Out:
#     first   last            email   age
# 1     jan    deo    jan@gmail.com  35.0
# 3   chris  henry  henry@gmail.com  23.0
# 7  parnel   wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='any')
# Out:
#     first   last            email   age
# 1     jan    deo    jan@gmail.com  35.0
# 3   chris  henry  henry@gmail.com  23.0
# 7  parnel   wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='all')
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 2     jon      dan             None  43.0
# 3   chris    henry  henry@gmail.com  23.0
# 4    None      NaN  kopal@gmail.com   NaN
# 5     NaN      NaN   pura@gmail.com  54.0
# 6      ab       cd             None  53.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='any')
# Out:
#     first   last            email   age
# 1     jan    deo    jan@gmail.com  35.0
# 3   chris  henry  henry@gmail.com  23.0
# 7  parnel   wine   wine@gmail.com  67.0

# %%
df.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
df.dropna(axis='index', how='any', subset=['email'])
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 3   chris    henry  henry@gmail.com  23.0
# 4    None      NaN  kopal@gmail.com   NaN
# 5     NaN      NaN   pura@gmail.com  54.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='any', subset=['email','last'])
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 3   chris    henry  henry@gmail.com  23.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.replace('NA',np.nan, inplace =True)
df.replace('Missing', np.nan, inplace =True)

# %%
df
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 2     jon      dan             None  43.0
# 3   chris    henry  henry@gmail.com  23.0
# 4    None      NaN  kopal@gmail.com   NaN
# 5     NaN      NaN   pura@gmail.com  54.0
# 6      ab       cd             None  53.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='any')
# Out:
#     first   last            email   age
# 1     jan    deo    jan@gmail.com  35.0
# 3   chris  henry  henry@gmail.com  23.0
# 7  parnel   wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='all')
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 2     jon      dan             None  43.0
# 3   chris    henry  henry@gmail.com  23.0
# 4    None      NaN  kopal@gmail.com   NaN
# 5     NaN      NaN   pura@gmail.com  54.0
# 6      ab       cd             None  53.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='any', subset=['email'])
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 3   chris    henry  henry@gmail.com  23.0
# 4    None      NaN  kopal@gmail.com   NaN
# 5     NaN      NaN   pura@gmail.com  54.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.dropna(axis='index', how='any', subset=['email','last'])
# Out:
#     first     last            email   age
# 0   corey  schafer  corey@gmail.com   NaN
# 1     jan      deo    jan@gmail.com  35.0
# 3   chris    henry  henry@gmail.com  23.0
# 7  parnel     wine   wine@gmail.com  67.0

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False   True
# 1  False  False  False  False
# 2  False  False   True  False
# 3  False  False  False  False
# 4   True   True  False   True
# 5   True   True  False  False
# 6  False  False   True  False
# 7  False  False  False  False

# %%
df.fillna('Missing')
# Out:
#      first     last            email      age
# 0    corey  schafer  corey@gmail.com  Missing
# 1      jan      deo    jan@gmail.com       35
# 2      jon      dan          Missing       43
# 3    chris    henry  henry@gmail.com       23
# 4  Missing  Missing  kopal@gmail.com  Missing
# 5  Missing  Missing   pura@gmail.com       54
# 6       ab       cd          Missing       53
# 7   parnel     wine   wine@gmail.com       67

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age']=df['age'].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# 45.833333333333336
